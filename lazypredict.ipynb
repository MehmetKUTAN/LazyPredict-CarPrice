# %% [markdown]
# <a href="https://colab.research.google.com/github/MehmetKUTAN/LazyPredict-CarPrice/blob/master/lazypredict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install lazypredict
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: lazypredict in /usr/local/lib/python3.7/dist-packages (0.2.12)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.3.5)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from lazypredict) (7.1.2)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.7/dist-packages (from lazypredict) (2.2.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from lazypredict) (4.64.1)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.7/dist-packages (from lazypredict) (0.90)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from lightgbm->lazypredict) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from lightgbm->lazypredict) (1.7.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->lazypredict) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->lazypredict) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->lazypredict) (3.1.0)

# %%
import lazypredict

# %%
import numpy as np
import pandas as pd
df=pd.read_csv("carData.csv")

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(7,7))
sns.pairplot(df)

# %%
plt.figure(figsize=(20,7))
sns.heatmap(df.corr(), annot=True, linewidths=.5, cmap='Blues')
plt.show()

# %%
print(df.Fuel_Type.value_counts())
print(df.Selling_type.value_counts())
print(df.Transmission.value_counts())
# Out:
# Petrol    239
# Diesel     60
# CNG         2
# Name: Fuel_Type, dtype: int64
# Dealer        195
# Individual    106
# Name: Selling_type, dtype: int64
# Manual       261
# Automatic     40
# Name: Transmission, dtype: int64

# %%
df.replace({'Fuel_Type':{'Petrol':0,'Diesel':1,'CNG':2}},inplace=True)
df.replace({'Selling_type':{'Dealer':0,'Individual':1}},inplace=True)
df.replace({'Transmission':{'Manual':0,'Automatic':1}},inplace=True)
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms  Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000          0
# 1      sx4  2013           4.75           9.54       43000          1
# 2     ciaz  2017           7.25           9.85        6900          0
# 3  wagon r  2011           2.85           4.15        5200          0
# 4    swift  2014           4.60           6.87       42450          1
#
#    Selling_type  Transmission  Owner
# 0             0             0      0
# 1             0             0      0
# 2             0             0      0
# 3             0             0      0
# 4             0             0      0

# %%
X = df.drop(['Car_Name','Selling_Price'],axis=1)
Y = df['Selling_Price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 20)

# %%
from lazypredict.Supervised import LazyClassifier, LazyRegressor

# %%
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models,pred = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████| 42/42 [00:02<00:00, 14.83it/s]
# [20:15:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# RandomForestRegressor                        0.97       0.98  0.79        0.28
# GradientBoostingRegressor                    0.97       0.97  0.84        0.07
# XGBRegressor                                 0.97       0.97  0.87        0.03
# BaggingRegressor                             0.96       0.96  0.99        0.05
# AdaBoostRegressor                            0.96       0.96  1.01        0.16
# DecisionTreeRegressor                        0.95       0.96  1.03        0.02
# KNeighborsRegressor                          0.95       0.96  1.05        0.01
# ExtraTreesRegressor                          0.93       0.94  1.24        0.24
# MLPRegressor                                 0.93       0.94  1.28        0.34
# LGBMRegressor                                0.91       0.92  1.42        0.02
# HistGradientBoostingRegressor                0.91       0.92  1.43        0.31
# LassoLarsIC                                  0.91       0.92  1.43        0.02
# TransformedTargetRegressor                   0.91       0.92  1.43        0.01
# Lars                                         0.91       0.92  1.43        0.01
# LinearRegression                             0.91       0.92  1.43        0.01
# Ridge                                        0.91       0.92  1.43        0.02
# BayesianRidge                                0.91       0.92  1.43        0.01
# SGDRegressor                                 0.91       0.92  1.44        0.01
# RidgeCV                                      0.91       0.92  1.45        0.01
# HuberRegressor                               0.90       0.91  1.53        0.01
# ElasticNetCV                                 0.89       0.91  1.56        0.15
# LinearSVR                                    0.89       0.90  1.59        0.01
# LassoCV                                      0.89       0.90  1.61        0.07
# LarsCV                                       0.87       0.89  1.69        0.02
# LassoLarsCV                                  0.87       0.89  1.69        0.03
# OrthogonalMatchingPursuitCV                  0.87       0.89  1.71        0.02
# RANSACRegressor                              0.87       0.88  1.72        0.05
# PassiveAggressiveRegressor                   0.86       0.88  1.76        0.01
# PoissonRegressor                             0.83       0.85  1.98        0.02
# OrthogonalMatchingPursuit                    0.82       0.84  2.03        0.01
# ExtraTreeRegressor                           0.79       0.82  2.16        0.02
# Lasso                                        0.77       0.80  2.28        0.01
# ElasticNet                                   0.73       0.77  2.45        0.04
# TweedieRegressor                             0.73       0.76  2.48        0.01
# NuSVR                                        0.65       0.69  2.80        0.02
# SVR                                          0.64       0.68  2.84        0.01
# GammaRegressor                               0.64       0.68  2.85        0.02
# KernelRidge                                  0.00       0.12  4.75        0.01
# DummyRegressor                              -0.15      -0.01  5.09        0.01
# LassoLars                                   -0.15      -0.01  5.09        0.01
# QuantileRegressor                           -0.25      -0.10  5.32        0.57
# GaussianProcessRegressor                  -367.70    -324.69 91.29        0.03
